# %% [markdown]
# # To demonstrate Regularisation over non linear model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('china_sales.csv')

# %%
df.head()
# Out:
#    Year         value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %%
df.describe()
# Out:
#              Year         value
# count    55.00000  5.500000e+01
# mean   1987.00000  1.437041e+12
# std      16.02082  2.500082e+12
# min    1960.00000  4.668518e+10
# 25%    1973.50000  1.395125e+11
# 50%    1987.00000  3.074800e+11
# 75%    2000.50000  1.268745e+12
# max    2014.00000  1.035480e+13

# %%
x = df.iloc[:,0].values
y = df.iloc[:,-1].values

# %%
x
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int64)

# %%
y
# Out:
# array([5.91841165e+10, 4.95570502e+10, 4.66851785e+10, 5.00973033e+10,
#        5.90622549e+10, 6.97091531e+10, 7.58794348e+10, 7.20570286e+10,
#        6.99934979e+10, 7.87188205e+10, 9.15062113e+10, 9.85620238e+10,
#        1.12160000e+11, 1.36770000e+11, 1.42255000e+11, 1.61162000e+11,
#        1.51628000e+11, 1.72349000e+11, 1.48382000e+11, 1.76857000e+11,
#        1.89650000e+11, 1.94369000e+11, 2.03550000e+11, 2.28950000e+11,
#        2.58082000e+11, 3.07480000e+11, 2.98806000e+11, 2.71350000e+11,
#        3.10722000e+11, 3.45957000e+11, 3.58973000e+11, 3.81455000e+11,
#        4.24934000e+11, 4.42875000e+11, 5.62261000e+11, 7.32032000e+11,
#        8.60844000e+11, 9.58159000e+11, 1.02528000e+12, 1.08945000e+12,
#        1.20526000e+12, 1.33223000e+12, 1.46191000e+12, 1.64993000e+12,
#        1.94175000e+12, 2.26860000e+12, 2.72978000e+12, 3.52309000e+12,
#        4.55843000e+12, 5.05942000e+12, 6.03966000e+12, 7.49243000e+12,
#        8.46162000e+12, 9.49060000e+12, 1.03548000e+13])

# %%
x = x.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1.12959624e+11])

# %%
lr.intercept_
# Out:
# -223013730867757.94

# %%
y_pred = lr.predict(x)
y_pred
# Out:
# array([-1.61286867e+12, -1.49990905e+12, -1.38694942e+12, -1.27398980e+12,
#        -1.16103018e+12, -1.04807055e+12, -9.35110930e+11, -8.22151306e+11,
#        -7.09191683e+11, -5.96232059e+11, -4.83272436e+11, -3.70312812e+11,
#        -2.57353189e+11, -1.44393565e+11, -3.14339414e+10,  8.15256821e+10,
#         1.94485306e+11,  3.07444929e+11,  4.20404553e+11,  5.33364176e+11,
#         6.46323800e+11,  7.59283424e+11,  8.72243047e+11,  9.85202671e+11,
#         1.09816229e+12,  1.21112192e+12,  1.32408154e+12,  1.43704116e+12,
#         1.55000079e+12,  1.66296041e+12,  1.77592004e+12,  1.88887966e+12,
#         2.00183928e+12,  2.11479891e+12,  2.22775853e+12,  2.34071815e+12,
#         2.45367778e+12,  2.56663740e+12,  2.67959702e+12,  2.79255665e+12,
#         2.90551627e+12,  3.01847589e+12,  3.13143552e+12,  3.24439514e+12,
#         3.35735477e+12,  3.47031439e+12,  3.58327401e+12,  3.69623364e+12,
#         3.80919326e+12,  3.92215288e+12,  4.03511251e+12,  4.14807213e+12,
#         4.26103175e+12,  4.37399138e+12,  4.48695100e+12])

# %%
y
# Out:
# array([5.91841165e+10, 4.95570502e+10, 4.66851785e+10, 5.00973033e+10,
#        5.90622549e+10, 6.97091531e+10, 7.58794348e+10, 7.20570286e+10,
#        6.99934979e+10, 7.87188205e+10, 9.15062113e+10, 9.85620238e+10,
#        1.12160000e+11, 1.36770000e+11, 1.42255000e+11, 1.61162000e+11,
#        1.51628000e+11, 1.72349000e+11, 1.48382000e+11, 1.76857000e+11,
#        1.89650000e+11, 1.94369000e+11, 2.03550000e+11, 2.28950000e+11,
#        2.58082000e+11, 3.07480000e+11, 2.98806000e+11, 2.71350000e+11,
#        3.10722000e+11, 3.45957000e+11, 3.58973000e+11, 3.81455000e+11,
#        4.24934000e+11, 4.42875000e+11, 5.62261000e+11, 7.32032000e+11,
#        8.60844000e+11, 9.58159000e+11, 1.02528000e+12, 1.08945000e+12,
#        1.20526000e+12, 1.33223000e+12, 1.46191000e+12, 1.64993000e+12,
#        1.94175000e+12, 2.26860000e+12, 2.72978000e+12, 3.52309000e+12,
#        4.55843000e+12, 5.05942000e+12, 6.03966000e+12, 7.49243000e+12,
#        8.46162000e+12, 9.49060000e+12, 1.03548000e+13])

# %%
from sklearn.linear_model import Ridge

# %%
Ri = Ridge(alpha=100000)

# %%
Ri.fit(x,y)
# Out:
# Ridge(alpha=100000)

# %%
print("Coefficient of Ridge:")
Ri.coef_
# Out:
# Coefficient of Ridge:
# array([1.37503986e+10])

# %%
print("Intercept of Ridge:")
Ri.intercept_
# Out:
# Intercept of Ridge:
# -25885000819692.61

# %%
y_predi = Ri.predict(x)
y_predi
# Out:
# array([1.06578040e+12, 1.07953080e+12, 1.09328120e+12, 1.10703160e+12,
#        1.12078200e+12, 1.13453240e+12, 1.14828279e+12, 1.16203319e+12,
#        1.17578359e+12, 1.18953399e+12, 1.20328439e+12, 1.21703479e+12,
#        1.23078519e+12, 1.24453558e+12, 1.25828598e+12, 1.27203638e+12,
#        1.28578678e+12, 1.29953718e+12, 1.31328758e+12, 1.32703798e+12,
#        1.34078837e+12, 1.35453877e+12, 1.36828917e+12, 1.38203957e+12,
#        1.39578997e+12, 1.40954037e+12, 1.42329077e+12, 1.43704116e+12,
#        1.45079156e+12, 1.46454196e+12, 1.47829236e+12, 1.49204276e+12,
#        1.50579316e+12, 1.51954356e+12, 1.53329396e+12, 1.54704435e+12,
#        1.56079475e+12, 1.57454515e+12, 1.58829555e+12, 1.60204595e+12,
#        1.61579635e+12, 1.62954675e+12, 1.64329714e+12, 1.65704754e+12,
#        1.67079794e+12, 1.68454834e+12, 1.69829874e+12, 1.71204914e+12,
#        1.72579954e+12, 1.73954993e+12, 1.75330033e+12, 1.76705073e+12,
#        1.78080113e+12, 1.79455153e+12, 1.80830193e+12])

# %%
y
# Out:
# array([5.91841165e+10, 4.95570502e+10, 4.66851785e+10, 5.00973033e+10,
#        5.90622549e+10, 6.97091531e+10, 7.58794348e+10, 7.20570286e+10,
#        6.99934979e+10, 7.87188205e+10, 9.15062113e+10, 9.85620238e+10,
#        1.12160000e+11, 1.36770000e+11, 1.42255000e+11, 1.61162000e+11,
#        1.51628000e+11, 1.72349000e+11, 1.48382000e+11, 1.76857000e+11,
#        1.89650000e+11, 1.94369000e+11, 2.03550000e+11, 2.28950000e+11,
#        2.58082000e+11, 3.07480000e+11, 2.98806000e+11, 2.71350000e+11,
#        3.10722000e+11, 3.45957000e+11, 3.58973000e+11, 3.81455000e+11,
#        4.24934000e+11, 4.42875000e+11, 5.62261000e+11, 7.32032000e+11,
#        8.60844000e+11, 9.58159000e+11, 1.02528000e+12, 1.08945000e+12,
#        1.20526000e+12, 1.33223000e+12, 1.46191000e+12, 1.64993000e+12,
#        1.94175000e+12, 2.26860000e+12, 2.72978000e+12, 3.52309000e+12,
#        4.55843000e+12, 5.05942000e+12, 6.03966000e+12, 7.49243000e+12,
#        8.46162000e+12, 9.49060000e+12, 1.03548000e+13])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("R2 Score of Ridge L2 Regularisation:")
r2_score(y,y_predi)
# Out:
# R2 Score of Ridge L2 Regularisation:
# 0.11980028466359993

# %%
print("Mean_Squared_Error of Ridge L2 Regularisation:")
mean_squared_error(y,y_predi)
# Out:
# Mean_Squared_Error of Ridge L2 Regularisation:
# 5.401580107994722e+24

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %%
def get_preds_ridge(x,y,alpha):
    model = Pipeline([
        ('Poly_features',PolynomialFeatures(degree=2)),
        ('ridge',Ridge(alpha=alpha))
    ])
    model.fit(x,y)
    return model.predict(x)

alphas = [0, 20, 200]
cs = ['r', 'g', 'b']

plt.figure(figsize=(10,6))
plt.plot(x, y, 'b+', label='Datapoints')

for alpha, c in zip(alphas, cs):
    preds = get_preds_ridge(x,y,alpha)
    plt.plot (sorted(x[:,0]),preds[np.argsort(x[:,0])],c, label = 'Alpha: {}'.format(alpha))
plt.legend()    
plt.show()
